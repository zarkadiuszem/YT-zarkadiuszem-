# %% [markdown]
# # Wprowadzenie - przypomnienie

# %% [markdown]
# **Dlaczego python** <br>
#
#
# 1.   Łatwy w obsłudze - zalecany do nauki - popularny
# 2.   Wielkia skala zastosowań - wartość komercyjna
# 3. Przydatny (tak jak R) w analizie danych

# %% [markdown]
# ## Wyświetlanie wyników

# %% [markdown]
# Co zostanie wyświetlone?

# %%
x = -2**2               # nie - bo tworzymy zmienną
print("hello world")    # tak - bo jest funkcja print (wbudowana funkcja print)
5 / 2.5                 # nie - bo nie ma funkcji print
print(x)                # tak
2 + 2                   # tak - bo jest na końcu
# Out:
# hello world
# -4
# 4

# %% [markdown]
# <h3>Trochę terminologii</h3>
#
# 1.   Kod (skrypt) został wykonany przez **interpreter** pythona linijka po linijce. Dlatego jest to język **interpretowany**
# 2.   Nie jest tu więc tworzony odrębny plik (przez **kompilator**)

# %%
print("Witajcie Studenci")
'Witajcie Studenci' # podobnie do return (a nie print) - tu jest taki string - automatyczne zwracanie ostatniej wartości
# Out:
# Witajcie Studenci
# 'Witajcie Studenci'

# %% [markdown]
# ## Kolejność wykonywania kodu
# Liczby z lewej strony [ ] określają kolejność wykonywania kodu przez programistę.
# Jeśli więc gdzieś wykonamy kod - np przypiszemy jakąś liczbę do zmiennej, to będzie ona dostępna nawet z wyższych pozycji notesu - o ile wykonamy polecenia później - liczy się moment wykonania a nie pozycja. Jeśli chcemy wykonać cały kod wybierz: Środowisko wykonawcze - Uruchom wszystko

# %% [markdown]
# <h3>Trochę terminologii</h3>
# W poniższym kodzie:
#
# 1.   **Zmienna** x (zmienna to nazwa, etykieta)
# 2.   **Wskazuje** na wartość 1 (jest referencją do obiektu x)
# 3. 1 to **obiekt**
# 4. = to **operator przypisania**

# %%
x = 1
'''nawet jeśli skasujemy tę komórkę z kodem zmienna x nadal będzie w pamięci komputera
musimy więc albo ponownie otworzyć notes albo Uruchom ponownie środowisko wykonawcze (z menu Środowiso wykonawcze)
albo skasować zmienną del x'''
# Out:
# 'nawet jeśli skasujemy tę komórkę z kodem zmienna x nadal będzie w pamięci komputera\nmusimy więc albo ponownie otworzyć notes albo Uruchom ponownie środowisko wykonawcze (z menu Środowiso wykonawcze)\nalbo skasować zmienną del x'

# %%
print(x)
del x
x
# Out:
# -4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-6826eae22fc3> in <cell line: 3>()
#       1 print(x)
#       2 del x
# ----> 3 x
#
# NameError: name 'x' is not defined

# %%
#zbyt długą linię (ponad 80 znaków) przerywamy \
a = 1\
+2\
+3
a

# %% [markdown]
# # Typy danych

# %% [markdown]
# ## Integers typ int
# Liczby całkowite 1, 10, -10 <br>
# Każdy typ danych - jaki poznamy - możemy nazywać obiektem

# %%
#assign to a variable
my_number = 10  # operator przypisania =
print(my_number)
2+2
wynik = my_number + my_number
wynik
wynik = my_number + wynik
wynik = my_number + wynik
wynik = wynik *10
wynik
# Out:
# 10
# 400

# %%
print(10 * 10)
number1 = 10
number2 = -10
result = number1 - number2
print(result)
print(type(result))
# Out:
# 100
# 20
# <class 'int'>

# %%
a = b = c = 2
milion = 1_000_000 # podkreślniki pomija
milion

# %%
#utworzenie kilku zmiennych naraz
a,b,c = 55.6,'ttt',90
print(a,b,c)
# Out:
# 55.6 ttt 90

# %% [markdown]
# ### Nazwy zmiennych
# **Identifier** - np nazwa funkcji, listy czy zmiennej
# wszystko jest case-sensitive (wilekość liter ma znaczenie)
# 1. Samoopisujące - np. name
# 2. Bez spacji - może być np my_name (Snake Case) lub myName (Camel Case)
# 3. Nie stosujemy symboli takich jak  !, @, #, $ (kropka) itd.
# 4. Nie zaczynamy od liczby
# 5. Nie używamy słów które mają szczególne znaczenie dla pythona

# %% [markdown]
# **Keywords** - zarezerwowane słowa

# %%
import keyword
print(keyword.kwlist)
len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
my_variable = 10
print(id(my_variable))
#gdzie jest zarezerwowana pamięć na moja zmienną - tworzenie zmiennej = przydzielanie przestrzeni w pamięci komputera
# Out:
# 135453568270864

# %%
a = 2
b = a
a = a + 1
print(a, b)

# %% [markdown]
# ### Obiekty mutowalne i niemutowalne
# Każdy typ danych - lista, zmienna int, float słownik to obiekt

# %%
# Przykład obiektów niemutowalnych
# tworzymy obiekt typu int 1 - nazywamy go a
a = 1
print(id(a))  # sprawdzamy miejsce w pamięci
# tworzymy drugą etykietę b i podpinamy ją do tego samego obiektu
b = a
print(id(b)) # sprawdzamy miejsce w pamięci
# przypisujemy do a 2 co oznacza że a nie wkazuje już na obiekt w którym jest 1 tylko na nowy w którym jest 2
a = 2
# w pierwszym obiekcie nadal jest 1
print(id(a))
#gdzie jest zarezerwowana pamięć na moja zmienną - tworzenie zmiennej = przydzielanie przestrzeni w pamięci komputera

print('a jest ', a, 'b jest ', b)

# %%
(2+2)*(2+2)

# %%
-2**2

# %% [markdown]
# ## Floating point typ float
# <br>
# (liczby zmienno-przecinkowe)
# Np. 1.2, 34.5, -3.2

# %%
print(3.2 / 3.4)
my_float = 3.3
print(type(my_float))
print(my_float)
# Out:
# 0.9411764705882354
# <class 'float'>
# 3.3

# %% [markdown]
# <h3>Trochę terminologii</h3>
#
# Python charakteryzuje się **dynamicznym typowaniem** oznacza to, że nie musimy deklarować typu zmiennej i możemy zmienić typ danych w dowolnym czasie. <br>
# Przeciwieństwem jest statyczne typowanie

# %%
a = 1
print(type(a))
a = "Arek"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Strings typ str
#
#
# Ciągi znaków - Łańcuch znaków <br>
# Uporządkowana sekwencja symboli <br>
#
# <h3>'Hello World'</h3>
# <h3>"2021"</h3>

# %% [markdown]
# INDEXY<br>
# *Wejść w komórkę żeby było równo* <br>
# A    n    a    k    o    n    d    a<br>
# 0    1    2    3    4    5    6    7<br>
# -8  -7   -6   -5   -4   -3   -2   -1

# %%
word = "Anakonda"
word[0]
# Out:
# 'A'

# %%
word[-8] # negatywne indeksy
# Out:
# 'A'

# %%
word[-1]
# Out:
# 'a'

# %%
len(word)
# Out:
# 8

# %% [markdown]
# ### Zadanie 1
# Napisz kod, który przypisze ostatnią literę napisu w zmiennej "word" <br> do zmiennej "ostatnia_litera", ale bez używania indeksowania od końca.

# %%
ostatnia_litera = word[len(word)-1]
ostatnia_litera

# %%
miłosz = '''Który skrzywdziłeś człowieka prostego
Śmiechem nad krzywdą jego wybuchając,
Gromadę błaznów koło siebie mając
Na pomieszanie dobrego i złego,

Choćby przed tobą wszyscy się skłonili
Cnotę i mądrość tobie przypisując,
Złote medale na twoją cześć kując,
Radzi że jeszcze jeden dzień przeżyli,

Nie bądź bezpieczny. Poeta pamięta
Możesz go zabić - narodzi się nowy.
Spisane będą czyny i rozmowy.

Lepszy dla ciebie byłby świt zimowy
I sznur i gałąź pod ciężarem zgięta.'''
print(miłosz)
# Out:
# Który skrzywdziłeś człowieka prostego
# Śmiechem nad krzywdą jego wybuchając,
# Gromadę błaznów koło siebie mając
# Na pomieszanie dobrego i złego,
#
# Choćby przed tobą wszyscy się skłonili
# Cnotę i mądrość tobie przypisując,
# Złote medale na twoją cześć kując,
# Radzi że jeszcze jeden dzień przeżyli,
#
# Nie bądź bezpieczny. Poeta pamięta
# Możesz go zabić - narodzi się nowy.
# Spisane będą czyny i rozmowy.
#
# Lepszy dla ciebie byłby świt zimowy
# I sznur i gałąź pod ciężarem zgięta.

# %%
len(miłosz)
#FUNKCJA len
# Out:
# 466

# %%
# do metod wrócimy w dlaszej części skryptu
szukane_słowo = ' i '
print(miłosz.find(szukane_słowo)) #pierwsze napotkanie fragmentu ciągu (indeks pozycji gdzie się zaczyna podciąg) - METODA find() właściwa do obiektów str
miłosz.rfind(szukane_słowo) #ostatnie napotkane
# Out:
# 132
# 437

# %%
imię = 'arek'
nazwisko = 'zyziel'

# %%
#konkatenacja
osoba = imię + ' ' + nazwisko
osoba
# Out:
# 'arek zyziel'

# %%
(osoba + ' ') * 3
# Out:
# 'arek zyziel arek zyziel arek zyziel '

# %% [markdown]
# ### Użycie wartości zmiennej w stringu

# %%
age = 20
print("My name is {} and I'm {}".format(imię, age))
# Out:
# My name is arek and I'm 20

# %%
# inna technika formatowania ciągu tekstowego: f-string literals
#formatowanie ciągów znaków
#jeśli tu pokaże się błąd -> uruchom ponownie środowisko wykonawcze
imię = "XXX"
nazwisko = "YYY"
prowadzący = f'Imię: {imię} \nNazwisko: {nazwisko}'
print(prowadzący)
# Out:
# Imię: XXX
# Nazwisko: YYY

# %% [markdown]
# ###Slicing

# %%
word = 'studiowanie'
word[1:3]
# Out:
# 'tu'

# %%
word[0:7:2]
#start : stop: step
# Out:
# 'suiw'

# %%
word[3:]
# Out:
# 'diowanie'

# %%
word[::2]
# Out:
# 'suiwne'

# %%
word[::-1]
# Out:
# 'einawoiduts'

# %%
# Nie można zmienić stringa - ciąg znaków jest niemutowalny
word[1] = "a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-22145435b134> in <cell line: 2>()
#       1 # Nie można zmienić stringa - ciąg znaków jest niemutowalny
# ----> 2 word[1] = "a"
#
# TypeError: 'str' object does not support item assignment

# %%
osoba1 = "Arkadiusz Bulka"
osoba2 = osoba1[:12] + 'ł' + osoba1[-2:]
osoba2
# Out:
# 'Arkadiusz Bułka'

# %%
# kolejna metoda dla obiektów str - zastępowanie fragmentów tekstu
name = 'arek,jarek,darek'
print(name.replace('arek','rufus')) #zwracamy nowy ciąg
name  # stary się nie zmienia
# Out:
# rufus,jrufus,drufus
# 'arek,jarek,darek'

# %%
#trzeci argument count
name.replace('arek','rufus', 1)
# Out:
# 'rufus,jarek,darek'

# %%
#konkatenacja
word = 'rufus mruk'
name = "My name is: "
print(name + word)
print('2' + '3')
# Out:
# My name is: rufus mruk
# 23

# %% [markdown]
# ### Kolejne metody przypisane do obiektów str

# %%
word.upper()
# Out:
# 'RUFUS MRUK'

# %%
word.lower()
# Out:
# 'rufus mruk'

# %%
word.capitalize()
# Out:
# 'Rufus mruk'

# %%
word.title()
# Out:
# 'Rufus Mruk'

# %%
sentence = name + ' ' + word
print(sentence)
#tworzymy listę dzielącą str w oparciu o spacje (metoda split)
print(sentence.split())
#tworzymy listę fragmentów dzieląc w oparciu o symbol "n"
print(sentence.split('n'))
# Out:
# My name is:  rufus mruk
# ['My', 'name', 'is:', 'rufus', 'mruk']
# ['My ', 'ame is:  rufus mruk']

# %% [markdown]
# ## Dynamiczne typowanie (Dynamic typing)
# Mogę raz przypisać **int** do danej zmiennej, a później do tej samej zmiennej przypisać **str** (zmienić jej typ) <br>
# Nie deklaruję wcześniej jaka to będzie zmienna

# %%
number = 10
print(type(number))

number = "arek"
print(type(number))

# %%
user_number = input('Enter a number ')
# funcja input wyświetli "Enter a number" - użytkownik ma coś wpisać z klawiatury i wcisnąć Enter. Wtedy:
# zwróci str (to co wpisze użytkownik)
# obiekt str zostanie przypisany do zmiennej user_number
print('Your number is: ', user_number) #funkcja print
type(user_number)
# Out:
# Enter a number 22
# Your number is:  22
# str

# %%
number1 = int(input('podaj ilosc: ')) #konwertowanie stringa na int za pomocą finkcji int()
number2 = int(input('podaj cene: '))
wartosc = number1 * number2
print('wartos wynosi: ', wartosc)
podatek = 0.23       # można też zapisać jako .23
wartosc_podatku = wartosc * podatek
wartosc_podatku
# Out:
# podaj ilosc: 2
# podaj cene: 3
# wartos wynosi:  6
# 1.3800000000000001

# %% [markdown]
# ### Zadanie 2
# Poproś użytkownika o podanie imienia, później zapytaj o wiek.
# Wypisz na ekranie: Cześć np. Arek urodziłeś się w 1999.

# %%
name = input('Podaj swoje imię')
age = int(input('podaj swój wiek'))
wiek = 2024 - age
print(f'Cześć {name}. Urodziłeś się w {wiek}')
# lepiej byłoby zaimportować datę - ale to zrobimy później
# Out:
# Podaj swoje imięarr
# podaj swój wiek22
# Cześć arr. Urodziłeś się w 2002

# %% [markdown]
# ## Wartości logiczne
#
# Booleans typ bool

# %%
a = True    # słowo kluczowe True - nie można skracać do T
b = False   # słowo kluczowe False
a != b
# Out:
# bool
